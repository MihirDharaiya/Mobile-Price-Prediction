# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('mobiles.csv')

# %%
df.head()
# Out:
#                                               url   Brand  \
# 0      https://gadgets.ndtv.com/vivo-v11-pro-5632    Vivo
# 1      https://gadgets.ndtv.com/vivo-v11-pro-5632    Vivo
# 2      https://gadgets.ndtv.com/vivo-v11-pro-5632    Vivo
# 3  https://gadgets.ndtv.com/redmi-note-5-pro-4607  Xiaomi
# 4  https://gadgets.ndtv.com/redmi-note-5-pro-4607  Xiaomi
#
#                                         Product Name             Model  \
# 0       Vivo V11 Pro (6GB RAM, 64GB) - Supernova Red           V11 Pro
# 1       Vivo V11 Pro (6GB RAM, 64GB) - Dazzling Gold           V11 Pro
# 2  Vivo V11 Pro (6GB RAM, 64GB) - Starry Night Black           V11 Pro
# 3             Redmi Note 5 Pro (4GB RAM, 64GB) - Red  Redmi Note 5 Pro
# 4       Redmi Note 5 Pro (6GB RAM, 64GB) - Rose Gold  Redmi Note 5 Pro
#
#                                          Picture URL  1 Stars  2 Stars  \
# 0  https://i.gadgets360cdn.com/products/large/153...        5        2
# 1  https://i.gadgets360cdn.com/products/large/153...        5        2
# 2  https://i.gadgets360cdn.com/products/large/153...        5        2
# 3  https://i.gadgets360cdn.com/products/large/151...        7        2
# 4  https://i.gadgets360cdn.com/products/large/151...        7        2
#
#    3 Stars  4 Stars  5 Stars  ...        Dimensions (mm)  \
# 0        6       18       70  ...  157.91 x 75.08 x 7.90
# 1        6       18       70  ...  157.91 x 75.08 x 7.90
# 2        6       18       70  ...  157.91 x 75.08 x 7.90
# 3        6       20       65  ...  158.60 x 75.40 x 8.05
# 4        6       20       65  ...  158.60 x 75.40 x 8.05
#
#                              Colours  Expandable storage up to (GB)   FM NFC  \
# 0        Dazzling Gold, Starry Black                            256  Yes  No
# 1        Dazzling Gold, Starry Black                            256  Yes  No
# 2        Dazzling Gold, Starry Black                            256  Yes  No
# 3  Black, Blue, Gold, Red, Rose Gold                            128  Yes  No
# 4  Black, Blue, Gold, Red, Rose Gold                            128  Yes  No
#
#   USB OTG Wi-Fi Direct           Processor make Infrared  \
# 0     Yes          Yes  Qualcomm Snapdragon 660       No
# 1     Yes          Yes  Qualcomm Snapdragon 660       No
# 2     Yes          Yes  Qualcomm Snapdragon 660       No
# 3     Yes          Yes  Qualcomm Snapdragon 636       No
# 4     Yes          Yes  Qualcomm Snapdragon 636       No
#
#                                           other_info
# 0  {'Weight (g)': '156.00', 'Sim 1 Supports 4G in...
# 1  {'Weight (g)': '156.00', 'Sim 1 Supports 4G in...
# 2  {'Weight (g)': '156.00', 'Sim 1 Supports 4G in...
# 3  {'Weight (g)': '181.00', 'Barometer': 'No', 'S...
# 4  {'Weight (g)': '181.00', 'Barometer': 'No', 'S...
#
# [5 rows x 54 columns]

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8775 entries, 0 to 8774
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            8775 non-null   object
#  1   Brand                          8775 non-null   object
#  2   Product Name                   5703 non-null   object
#  3   Model                          8775 non-null   object
#  4   Picture URL                    8775 non-null   object
#  5   1 Stars                        8775 non-null   int64
#  6   2 Stars                        8775 non-null   int64
#  7   3 Stars                        8775 non-null   int64
#  8   4 Stars                        8775 non-null   int64
#  9   5 Stars                        8775 non-null   int64
#  10  Total Ratings                  6036 non-null   object
#  11  Price in India                 5703 non-null   object
#  12  Battery capacity (mAh)         8508 non-null   float64
#  13  Processor                      8493 non-null   object
#  14  Operating system               8466 non-null   object
#  15  Rear camera                    8767 non-null   object
#  16  Front camera                   8738 non-null   object
#  17  Internal storage               8293 non-null   object
#  18  Resolution                     8230 non-null   object
#  19  RAM                            8130 non-null   object
#  20  Form factor                    8129 non-null   object
#  21  Screen size (inches)           8693 non-null   float64
#  22  Wi-Fi                          8686 non-null   object
#  23  Bluetooth                      8677 non-null   object
#  24  Touchscreen                    8642 non-null   object
#  25  Expandable storage             8447 non-null   object
#  26  Launched                       8425 non-null   object
#  27  Accelerometer                  8424 non-null   object
#  28  GPS                            8409 non-null   object
#  29  Number of SIMs                 8349 non-null   object
#  30  Sim 1 4G/ LTE                  6616 non-null   object
#  31  Sim 2 4G/ LTE                  6616 non-null   object
#  32  Sim 1 3G                       6565 non-null   object
#  33  Sim 2 3G                       6565 non-null   object
#  34  Sim 2 GSM/CDMA                 6370 non-null   object
#  35  Sim 1 GSM/CDMA                 6370 non-null   object
#  36  Proximity sensor               8349 non-null   object
#  37  Ambient light sensor           8221 non-null   object
#  38  Rear flash                     7914 non-null   object
#  39  Compass/ Magnetometer          7723 non-null   object
#  40  Gyroscope                      7415 non-null   object
#  41  Expandable storage type        7323 non-null   object
#  42  Headphones                     7198 non-null   object
#  43  Removable battery              7091 non-null   object
#  44  Dimensions (mm)                6997 non-null   object
#  45  Colours                        6923 non-null   object
#  46  Expandable storage up to (GB)  6907 non-null   object
#  47  FM                             6897 non-null   object
#  48  NFC                            6834 non-null   object
#  49  USB OTG                        6710 non-null   object
#  50  Wi-Fi Direct                   6313 non-null   object
#  51  Processor make                 6243 non-null   object
#  52  Infrared                       6190 non-null   object
#  53  other_info                     8775 non-null   object
# dtypes: float64(2), int64(5), object(47)
# memory usage: 3.6+ MB

# %%
df = df[['Price in India','RAM','Resolution','Processor','Battery capacity (mAh)','Internal storage','Expandable storage up to (GB)','Screen size (inches)']]

# %%
100* df.isnull().sum() / len(df)
# Out:
# Price in India                   35.008547
# RAM                               7.350427
# Resolution                        6.210826
# Processor                         3.213675
# Battery capacity (mAh)            3.042735
# Internal storage                  5.492877
# Expandable storage up to (GB)    21.287749
# Screen size (inches)              0.934473
# dtype: float64

# %%
df[df['RAM'].isnull()]
# Out:
#      Price in India  RAM       Resolution Processor  Battery capacity (mAh)  \
# 44         ₹ 35,999  NaN  750x1334 pixels       NaN                     NaN
# 45         ₹ 35,999  NaN  750x1334 pixels       NaN                     NaN
# 46         ₹ 50,999  NaN  750x1334 pixels       NaN                     NaN
# 49         ₹ 50,999  NaN  750x1334 pixels       NaN                     NaN
# 50         ₹ 50,999  NaN  750x1334 pixels       NaN                     NaN
# ...             ...  ...              ...       ...                     ...
# 8748            NaN  NaN              NaN       NaN                   650.0
# 8753            NaN  NaN   240x240 pixels       NaN                  1500.0
# 8766            NaN  NaN              NaN       NaN                     NaN
# 8773            NaN  NaN              NaN       NaN                     NaN
# 8774            NaN  NaN              NaN       NaN                     NaN
#
#      Internal storage Expandable storage up to (GB)  Screen size (inches)
# 44               64GB                           NaN                  4.70
# 45               64GB                           NaN                  4.70
# 46               64GB                           NaN                  4.70
# 49               64GB                           NaN                  4.70
# 50               64GB                           NaN                  4.70
# ...               ...                           ...                   ...
# 8748             32MB                           NaN                  1.44
# 8753              NaN                           NaN                   NaN
# 8766              NaN                           NaN                  6.45
# 8773              NaN                           NaN                  6.20
# 8774              NaN                           NaN                  5.60
#
# [645 rows x 8 columns]

# %%
df['RAM'] = df['RAM'].str.replace("GB", "")
df['RAM'] = df['RAM'].str.replace("MB", "")
df['RAM'] = df['RAM'].astype('float')

# %%
df['RAM'].value_counts()
# Out:
# 1.000      1779
# 2.000      1651
# 3.000      1300
# 4.000      1180
# 512.000     802
# 6.000       578
# 8.000       320
# 256.000     221
# 1.500        91
# 12.000       63
# 768.000      42
# 64.000       33
# 32.000       27
# 128.000      21
# 16.000        6
# 384.000       5
# 10.000        2
# 1.024         2
# 290.000       2
# 150.000       2
# 20.000        1
# 168.000       1
# 2.048         1
# Name: RAM, dtype: int64

# %%
df = (df[df['RAM'] <= 16.0]) 
df = (df[df['RAM'] >= 2.0])

# %%
df['RAM'].value_counts()
# Out:
# 2.000     1651
# 3.000     1300
# 4.000     1180
# 6.000      578
# 8.000      320
# 12.000      63
# 16.000       6
# 10.000       2
# 2.048        1
# Name: RAM, dtype: int64

# %%
from sklearn.impute import SimpleImputer
missingvalues = SimpleImputer(missing_values = np.NaN,strategy='median')
x = df.iloc[:,1].values
x = x.reshape(-1,1)
df.iloc[:,1] = missingvalues.fit_transform(x)

# %%
sns.set(rc = {'figure.figsize':(12,8)})
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df['Expandable storage up to (GB)'] = df['Expandable storage up to (GB)'].str.replace("GB", "")
df['Expandable storage up to (GB)'] = df['Expandable storage up to (GB)'].str.replace("TB", "")
df['Expandable storage up to (GB)'] = df['Expandable storage up to (GB)'].astype('float')

# %%
df.head()
# Out:
#   Price in India  RAM        Resolution         Processor  \
# 0       ₹ 28,990  6.0  1080x2340 pixels         octa-core
# 1       ₹ 22,654  6.0  1080x2340 pixels         octa-core
# 2       ₹ 23,990  6.0  1080x2340 pixels         octa-core
# 3       ₹ 11,290  4.0  1080x2160 pixels  1.8GHz octa-core
# 4       ₹ 12,900  4.0  1080x2160 pixels  1.8GHz octa-core
#
#    Battery capacity (mAh) Internal storage  Expandable storage up to (GB)  \
# 0                  3400.0             64GB                          256.0
# 1                  3400.0             64GB                          256.0
# 2                  3400.0             64GB                          256.0
# 3                  4000.0             64GB                          128.0
# 4                  4000.0             64GB                          128.0
#
#    Screen size (inches)
# 0                  6.41
# 1                  6.41
# 2                  6.41
# 3                  5.99
# 4                  5.99

# %%
df['Internal storage'] = df['Internal storage'].str.replace("GB", "")
df['Internal storage'] = df['Internal storage'].str.replace("MB", "")
df['Internal storage'] = df['Internal storage'].astype('float')

# %%
df.describe()
# Out:
#                RAM  Battery capacity (mAh)  Internal storage  \
# count  5101.000000             5041.000000       5074.000000
# mean      3.690266             3531.515176         53.304691
# std       1.971286              955.899015         52.029960
# min       2.000000              500.000000          4.000000
# 25%       2.000000             3000.000000         16.000000
# 50%       3.000000             3315.000000         32.000000
# 75%       4.000000             4000.000000         64.000000
# max      16.000000            18000.000000        512.000000
#
#        Expandable storage up to (GB)  Screen size (inches)
# count                    3718.000000           5062.000000
# mean                     1452.928725              5.740905
# std                     32940.798928              0.664764
# min                         1.000000              1.400000
# 25%                       128.000000              5.200000
# 50%                       200.000000              5.700000
# 75%                       256.000000              6.300000
# max                   1000000.000000              8.000000

# %%
df['Price in India'] = df['Price in India'].str.replace("₹ ", "")
df['Price in India'] = df['Price in India'].str.replace(",", "")
df['Price in India'] = df['Price in India'].astype('float')

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
for i in range(1,8):
    y = df.iloc[:,i].values
    df.iloc[:,i] = labelencoder.fit_transform(y)
    x = y.reshape(-1,1)

# %%
df.describe()
# Out:
#        Price in India          RAM   Resolution    Processor  \
# count     3659.000000  5101.000000  5101.000000  5101.000000
# mean     16579.681060     2.069006    47.464811   107.525975
# std      17108.975653     1.702116    33.823547    70.564033
# min        189.000000     0.000000     0.000000     0.000000
# 25%       7209.500000     0.000000    10.000000    32.000000
# 50%      10999.000000     2.000000    46.000000   103.000000
# 75%      17999.000000     3.000000    76.000000   178.000000
# max     178000.000000     8.000000   100.000000   215.000000
#
#        Battery capacity (mAh)  Internal storage  \
# count             5101.000000       5101.000000
# mean               131.057244          3.955695
# std                 61.074499          1.583740
# min                  0.000000          0.000000
# 25%                 93.000000          2.000000
# 50%                131.000000          4.000000
# 75%                171.000000          5.000000
# max                238.000000          9.000000
#
#        Expandable storage up to (GB)  Screen size (inches)
# count                    5101.000000           5101.000000
# mean                        9.642423             51.509900
# std                         4.372772             25.835174
# min                         0.000000              0.000000
# 25%                         6.000000             28.000000
# 50%                         8.000000             40.000000
# 75%                        16.000000             72.000000
# max                        16.000000            119.000000

# %%
df.describe()
# Out:
#        Price in India          RAM   Resolution    Processor  \
# count     3659.000000  5101.000000  5101.000000  5101.000000
# mean     16579.681060     2.069006    47.464811   107.525975
# std      17108.975653     1.702116    33.823547    70.564033
# min        189.000000     0.000000     0.000000     0.000000
# 25%       7209.500000     0.000000    10.000000    32.000000
# 50%      10999.000000     2.000000    46.000000   103.000000
# 75%      17999.000000     3.000000    76.000000   178.000000
# max     178000.000000     8.000000   100.000000   215.000000
#
#        Battery capacity (mAh)  Internal storage  \
# count             5101.000000       5101.000000
# mean               131.057244          3.955695
# std                 61.074499          1.583740
# min                  0.000000          0.000000
# 25%                 93.000000          2.000000
# 50%                131.000000          4.000000
# 75%                171.000000          5.000000
# max                238.000000          9.000000
#
#        Expandable storage up to (GB)  Screen size (inches)
# count                    5101.000000           5101.000000
# mean                        9.642423             51.509900
# std                         4.372772             25.835174
# min                         0.000000              0.000000
# 25%                         6.000000             28.000000
# 50%                         8.000000             40.000000
# 75%                        16.000000             72.000000
# max                        16.000000            119.000000

# %%
df.isnull().sum()
# Out:
# Price in India                   1442
# RAM                                 0
# Resolution                          0
# Processor                           0
# Battery capacity (mAh)              0
# Internal storage                    0
# Expandable storage up to (GB)       0
# Screen size (inches)                0
# dtype: int64

# %%
df = df.dropna(subset=['Price in India'])

# %%
df.isnull().sum()
# Out:
# Price in India                   0
# RAM                              0
# Resolution                       0
# Processor                        0
# Battery capacity (mAh)           0
# Internal storage                 0
# Expandable storage up to (GB)    0
# Screen size (inches)             0
# dtype: int64

# %%
sns.set(rc = {'figure.figsize':(12,8)})
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.set(rc = {'figure.figsize':(12,8)})
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
# df = df.drop(columns=['Resolution'])

# %%
sns.set(rc = {'figure.figsize':(12,8)})
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
X = df[['RAM','Processor','Battery capacity (mAh)','Internal storage','Expandable storage up to (GB)','Screen size (inches)']]
y = df[['Price in India']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (2561, 6) (1098, 6) (2561, 1) (1098, 1)

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(X_test,y_test)
# Out:
# 0.29327909813945485

# %%
reg.coef_
# Out:
# array([[3489.37576152,   15.70520824,  -56.34270095, 1092.3730289 ,
#         1020.75128102,   43.83537471]])

# %%
reg.predict(X_test)
# Out:
# array([[20936.91202526],
#        [28787.13214288],
#        [28787.13214288],
#        ...,
#        [17039.25281948],
#        [19030.54373542],
#        [ 7888.48134156]])

# %%
from scipy.stats import norm
from scipy import stats
sns.distplot(df['Price in India'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Price in India'], plot=plt)
# Out:
# C:\Users\Bharg\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# df[df['RAM'] <= 16]

# %%
from sklearn.tree import DecisionTreeRegressor 
regressor = DecisionTreeRegressor(random_state = 0) 
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# predicting a new value
  
# test the output by changing values, like 3750
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([10687.4, 16990. , 16990. , ..., 17085. , 12999. ,  8990. ])

# %%
regressor.score(X_test,y_test)
# Out:
# 0.7907114476431047

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
MAE = mean_absolute_error(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
RMSE = np.sqrt(MSE)

# %%
RMSE
# Out:
# 7988.2647368988055

# %%
df['Price in India'].mean()
# Out:
# 16579.681060399016

# %%
from sklearn import tree
tree.plot_tree(regressor,max_depth=2)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor(n_estimators = 100, random_state = 0)
forest.fit(X_train, y_train)
# Out:
# C:\Users\Bharg\AppData\Local\Temp/ipykernel_18240/1329365686.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   forest.fit(X_train, y_train)
# RandomForestRegressor(random_state=0)

# %%
y_pred_forest = forest.predict(X_test)

# %%
y_pred_forest
# Out:
# array([10677.4980542 , 20708.8615    , 20708.8615    , ...,
#        14989.32083333, 12642.52330952,  8719.275     ])

# %%
forest.score(X_test,y_test)
# Out:
# 0.8128428875609734

# %%
MAE = mean_absolute_error(y_test,y_pred_forest)
MSE = mean_squared_error(y_test,y_pred_forest)
RMSE = np.sqrt(MSE)

# %%
RMSE
# Out:
# 7554.102620283795

# %%
from sklearn.svm import SVR
reg_svr = SVR(kernel='linear')
reg_svr.fit(X_train, y_train)
# Out:
# C:\Users\Bharg\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVR(kernel='linear')

# %%
y_pred_svr = reg_svr.predict(X_test)

# %%
y_pred_svr
# Out:
# array([16588.81891527, 18576.73945299, 18576.73945299, ...,
#        12383.46230408, 14604.52289942, 11141.38777196])

# %%
reg_svr.score(X_test,y_test)
# Out:
# 0.12252003817551271

# %%
# X = df[['RAM','Processor','Battery capacity (mAh)','Internal storage','Expandable storage up to (GB)','Screen size (inches)']]
forest.predict([[4,44,105,3,8,45]])
# Out:
# array([19429.24565693])

# %%
df.value_counts()
# Out:
# Price in India  RAM  Resolution  Processor  Battery capacity (mAh)  Internal storage  Expandable storage up to (GB)  Screen size (inches)
# 13999.0         3    8           200        93                      5                 16                             57                      6
# 9599.0          2    83          103        168                     4                 8                              67                      5
# 40998.0         5    25          178        207                     6                 11                             85                      5
# 3799.0          0    76          7          26                      1                 5                              24                      4
# 8499.0          3    83          71         168                     4                 8                              70                      4
#                                                                                                                                             ..
# 8285.0          2    23          100        139                     4                 8                              72                      1
# 8293.0          0    76          31         46                      2                 4                              24                      1
# 8299.0          0    76          17         47                      1                 4                              24                      1
#                      78          71         127                     2                 16                             40                      1
# 178000.0        7    100         143        203                     8                 16                             119                     1
# Length: 2944, dtype: int64
